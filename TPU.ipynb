# %% [markdown]
# <a href="https://colab.research.google.com/github/Mingyu-dev/Mingyu_dev/blob/main/TPU.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # EE 508 Reading Assignment 2:
# You can access paper using this [link](https://arxiv.org/pdf/1704.04760.pdf). Please refer to this [guideline](http://ccr.sigcomm.org/online/files/p83-keshavA.pdf) on how to read a research paper.

# %% [markdown]
# ### Q1: (1 Point)
#
# **Disallowed** list:
# - You **MAY NOT** collaborate with anyone else on this assignment. This means you cannot talk to anyone else about the assignment until after deadline.
# - You **MAY NOT** use ChatGPT and services like that
#
# **Allowed** list:
# - Notes including any slides from the class
# - The textbooks
# - The given paper

# %% [markdown]
# ### A1:
#
# I affirm I have read these exam rules and will follow them. Failure to do so may subject me to sanctions including an F in the course.
#
# **Type your full name to affirm you have read the above statement:**

# %% [markdown]
# Mingyu Zhao

# %% [markdown]
# ----
# ### Q2 Summary (24 Points):
#
# Summarize the main objectives and contributions of the paper.

# %% [markdown]
# The paper evaluates the performance, cost-effectiveness, and energy efficiency of Google's custom Tensor Processing Unit (TPU) for neural network inference in datacenters,shows its significant importance over GPUs and CPUs.

# %% [markdown]
# ---
# ### Q3 Comprehension (15 Points):
# - What is a Tensor Processing Unit (TPU) and how does it differ from traditional CPUs and GPUs in terms of design and purpose?
# - Why is there a need for specialized hardware like TPUs in modern data centers?

# %% [markdown]
# A3:A Tensor Processing Unit is a custom ASIC developed by Google for accelerating neural network inference in data centers. TPUs feature a specialized matrix multiplication unit and on-chip memory designed specifically for neural network operations, focusing on integer arithmetic for efficiency.
#
# First, growing neural network workloads.These workloads require massive matrix operations that don't map efficiently to general-purpose architectures.Secondly, specialized hardware like TPUs can deliver orders of magnitude improvements in performance per watt, with high effiency and economic friendly.

# %% [markdown]
# ---
# ### Q4 Technical Deep Dive (15 Points):
# - Describe the architecture of the TPU. How is it optimized for machine learning workloads?
# - How does the memory hierarchy of the TPU differ from traditional processors, and why is this significant for tensor computations?
# - What are systolic arrays, and why are they used in TPUs?

# %% [markdown]
# ### A4:
#
# It features a large matrix multiply unit as its core computational element. It also includes software-managed on-chip memory for data handling. It also uses a systolic array architecture to optimize data flow and reduce memory access overhead.
#
# It is specialized for the compute-intensive matrix operations common in neural networks.It uses integer arithmetic to trade precision for efficiency.
#
# Systolic arrays are architectures that efficiently pass data between processing elements in a rhythmic fashion.They flow through the computation elements with minimal overhead.Also the pipeline pattern makes the output consistent and reduce the need for cache, improving computational efficiency for matrix operations.

# %% [markdown]
# ---
# ### Q5 Evaluation (15 Points):
# - How does the TPU's performance compare to contemporary CPUs and GPUs for machine learning tasks?
# - What benchmarks or workloads were used to evaluate the TPU's performance in the datacenter?
# - Discuss the TPU's performance per watt. Why is energy efficiency crucial in datacenter environments?
# - What types of machine learning models and tasks are best suited for TPUs?
# - How have TPUs impacted the training times of large-scale models at Google?

# %% [markdown]
# ### A5:
#
#  TPUs significantly outperform contemporary CPUs and GPUs in machine learning inference tasks.
#
#  Evaluated using production neural network applications (MLPs, CNNs, LSTMs) representing 95% of datacenter inference workloads.
#
#  Reducing power consumption lowers operational costs and allows for higher computational density within datacenters, enabling more computations per unit of energy.
#
# MLPs,CNNs, RNNs,LSTM
#
# Their specialized architecture reduces the time needed to process large datasets, but training often still relies on GPUs.

# %% [markdown]
# ---
# ### Q6 Contextual Understanding (10 Points):
# - What are some of the challenges faced in deploying TPUs in datacenters?
# - Are there specific machine learning tasks or models that TPUs might struggle with compared to other hardware?

# %% [markdown]
# ### A6:
#
# First it is about integration complexity. They require adaptation of existing datacenter infrastructure and workflows. Secondly it is about power and cooling. We must spend energy to cool the system to make it work at high performance.
#
# It may lose precision when dealing with floating-point intensive tasks.

# %% [markdown]
# ---
# ### Q7 Discussion and Critique (10 points):
# - What are the strengths and weaknesses of the paper's methodology and analysis?
# - Are there any potential biases or assumptions in the paper that you disagree with or find questionable?

# %% [markdown]
# ### A7:
# Strength: The paper provides a thorough analysis of TPU performance across multiple dimensions including throughput, latency, energy efficiency, and cost-effectiveness.
# weakness: They should use multiple software to explore the software utilization impact.
#
# The paper is carried out by google as a company, and may lose some true perspective outside the company.

# %% [markdown]
# ---
# ### Q8 Reflection (10 Points):
# - How do TPUs fit into the larger trend of custom hardware accelerators for machine learning, such as FPGAs and ASICs?
# - Discuss the trade-offs between general-purpose hardware (like CPUs) and specialized hardware (like TPUs) in the context of evolving machine learning workloads.

# %% [markdown]
# ### A8:
#
# TPUs are specifically designed for tensor operations and neural network inference, and they are more specilize than FPGAs.
#
# CPUs offer great flexibility for diverse workloads but with lower efficiency for specialized tasks. TPUs offers more effiency when doing matrix mulitiplicaiton and less flexibility.
